# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinash01-Arch/20A91A05J4_Avinash_CSE-C/blob/main/weight%20in%20kg%20to%20pounds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kilograms=float(input('enter weight in kg to pounds:'))
pounds=kilograms*2.2
print('weight equals %0.1f ' %(pounds))
print('weight equals',pounds)
print('weight equals {}'.format(pounds))
print(f'weight equals{pounds}')
print ('weight equals'+str(pounds)+'')
# Out:
# enter weight in kg to pounds:5
# weight equals 11.0
# weight equals 11.0
# weight equals 11.0
# weight equals11.0
# weight equals11.0
